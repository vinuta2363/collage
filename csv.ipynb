# %% [markdown]
# <a href="https://colab.research.google.com/github/vinuta2363/collage/blob/main/csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
x=iris['SepalLengthCm']
y=iris['SepalWidthCm']
plt.scatter(x,y)
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("scatter plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
x=iris['SepalLengthCm']
y=iris['SepalWidthCm']
color={'Iris-setosa':'red','Iris-virginica':'green','Iris-versicolor':'blue'}
species_color=iris['Species'].map(color)
plt.scatter(x,y,c=species_color)
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.title("scatter plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Iris.csv')
species_counts=iris['Species'].value_counts()
plt.bar(species_counts.index,species_counts.values,color='cyan')
plt.xlabel("Species")
plt.ylabel("count")
plt.grid(axis='y')
plt.title("number of flowers by species")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
plt.hist(iris['PetalLengthCm'],bins=10,color='lightgreen',edgecolor='black')
plt.xlabel("PetalLengthCm")
plt.ylabel("frequency")
plt.title("distribution of petal length")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
species=iris['Species'].unique()
data=[iris[iris['Species']==s]['PetalLengthCm']for s in species ]
plt.boxplot(data,labels=species)
plt.xlabel("species")
plt.ylabel("PetalLengthCm")
plt.title("compare petal length between species")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2036406839.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data,labels=species)

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/Irisdataset.csv')
plt.scatter(iris['PetalLengthCm'], iris['PetalWidthCm'], color='purple', alpha=0.6)
plt.title("Petal Length vs Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.show()
